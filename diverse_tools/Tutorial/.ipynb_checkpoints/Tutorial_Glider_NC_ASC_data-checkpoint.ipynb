# %% [markdown]
# # Importando módulos

# %%
import obspy
import os
import glob
import numpy as np
from collections import defaultdict
import pandas as pd
import glidertools as gt


#para plotar as figuras
import matplotlib.pyplot as plt
from matplotlib.transforms import offset_copy
import matplotlib.ticker as ticker
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import ListedColormap
import matplotlib.dates as mdates
from mpl_toolkits.axes_grid1.inset_locator import InsetPosition,inset_axes
import matplotlib.colors as colors
import matplotlib.cm as cm
from matplotlib.dates import YearLocator, MonthLocator, DayLocator, HourLocator, MinuteLocator, SecondLocator, DateFormatter
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

from datetime import datetime,timedelta,date
from tqdm import tqdm

from shapely.geometry.polygon import LinearRing

import cartopy.io.shapereader as shpreader
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %% [markdown]
# # Lista de Funções

# %%
def dm(x):
    south = False
    
    if x<0:
        south = True
        x = abs(x)
        
    degrees = int(x) // 100
    minutes = x - 100*degrees
    
    x = degrees + minutes/60
    if south:
        x = -x
    return x

# %%
def check_datetime_in_period(datetime_lst,dataf):
    '''
    Function to check if the dates in data set are inside the chosen time period
    
    '''
    array_to_plot_by_xlim = []
    for x,c in enumerate(datetime_lst):
        lista_temp = []
        for t,y in enumerate(dataf['DATETIME'].values):
            if y == c.date():
                lista_temp.append(np.array(dataf[dataf['DATETIME'] == y]['NUMBER_HOUR'].tolist()[0]))
        array_to_plot_by_xlim.append(lista_temp)
   
    data_x_axis = []
    for x,c in enumerate(array_to_plot_by_xlim):
        if c != []:
            data_x_axis.append(c[0])
        else:
            data_x_axis.append(np.zeros_like(np.arange(24)))

    data_x_axis = np.array(data_x_axis).T

    return data_x_axis
#----------------------------

# %%
FOLDER_OUTPUT = '/home/dIOGOLOC/dados_posdoc/gliders_project/OUTPUT/'

# %% [markdown]
# # Extraindo informações dos arquivos ".log" e criando um dataframe em PANDAS

# %% [markdown]
# ## Exemplo de dois mergulhos

# %%
os.chdir('/run/media/dIOGOLOC/8d2362fc-3b46-49a7-a864-19b2a6ad097b/diogoloc/dados_posdoc/gliders_project/gliders_data/NetCDF_data/campanha_08/')

# %%
filenames = sorted(glob.glob('*.nc'))

# %% [markdown]
# %columns: elaps_t_0000,elaps_t,depth,head,pitchAng,rollAng,pitchCtl,rollCtl,vbdCC,rec,GC_phase,sbect.condFreq,sbect.tempFreq

# %%
names = [
    'time',
    'dives',
    'latitude',
    'longitude',
    'depth'
]

ds_dict_lst_lat = []
ds_dict_lst_lon = []
ds_dict_lst_dpt = []
ds_dict_lst_time = []
ds_dict_lst_timelapse = []
ds_dict_lst_dive = []

for i in tqdm(filenames):
    dic_ds = gt.load.seaglider_basestation_netCDFs(i, names,verbose=False)
    ds_dict_lst_dive.append(dic_ds['sg_data_point'].attrs['number_of_dives'])
    ds_dict_lst_lat.append(dic_ds['sg_data_point'].attrs['geospatial_lat_min'])
    ds_dict_lst_lon.append(dic_ds['sg_data_point'].attrs['geospatial_lon_min'])
    ds_dict_lst_dpt.append(dic_ds['sg_data_point'].attrs['geospatial_vertical_max']*-1)
    ds_dict_lst_time.append(mdates.date2num(obspy.UTCDateTime(dic_ds['sg_data_point'].attrs['time_coverage_start'])))
    ds_dict_lst_timelapse.append(obspy.UTCDateTime(dic_ds['sg_data_point'].attrs['time_coverage_end'])-obspy.UTCDateTime(dic_ds['sg_data_point'].attrs['time_coverage_start']))
# Out:
#   0%|                                                    | 0/42 [00:00<?, ?it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   2%|█                                           | 1/42 [00:00<00:23,  1.75it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   5%|██                                          | 2/42 [00:01<00:20,  1.98it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   7%|███▏                                        | 3/42 [00:01<00:20,  1.93it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  10%|████▏                                       | 4/42 [00:02<00:18,  2.02it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  12%|█████▏                                      | 5/42 [00:02<00:17,  2.10it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  14%|██████▎                                     | 6/42 [00:02<00:16,  2.14it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  17%|███████▎                                    | 7/42 [00:03<00:16,  2.11it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  19%|████████▍                                   | 8/42 [00:03<00:16,  2.10it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  21%|█████████▍                                  | 9/42 [00:04<00:15,  2.12it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  24%|██████████▏                                | 10/42 [00:04<00:16,  1.93it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  26%|███████████▎                               | 11/42 [00:05<00:15,  1.98it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  29%|████████████▎                              | 12/42 [00:05<00:14,  2.06it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  31%|█████████████▎                             | 13/42 [00:06<00:14,  1.99it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  33%|██████████████▎                            | 14/42 [00:06<00:13,  2.07it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  36%|███████████████▎                           | 15/42 [00:07<00:12,  2.10it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  38%|████████████████▍                          | 16/42 [00:07<00:12,  2.14it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  40%|█████████████████▍                         | 17/42 [00:08<00:11,  2.14it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  43%|██████████████████▍                        | 18/42 [00:08<00:11,  2.18it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  45%|███████████████████▍                       | 19/42 [00:09<00:10,  2.19it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  48%|████████████████████▍                      | 20/42 [00:09<00:10,  2.18it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  50%|█████████████████████▌                     | 21/42 [00:10<00:09,  2.17it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  52%|██████████████████████▌                    | 22/42 [00:10<00:09,  2.07it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  55%|███████████████████████▌                   | 23/42 [00:11<00:08,  2.13it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  57%|████████████████████████▌                  | 24/42 [00:11<00:08,  2.14it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  60%|█████████████████████████▌                 | 25/42 [00:11<00:07,  2.18it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  62%|██████████████████████████▌                | 26/42 [00:12<00:07,  2.22it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  64%|███████████████████████████▋               | 27/42 [00:12<00:06,  2.23it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  67%|████████████████████████████▋              | 28/42 [00:13<00:06,  2.24it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  69%|█████████████████████████████▋             | 29/42 [00:13<00:05,  2.26it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  71%|██████████████████████████████▋            | 30/42 [00:14<00:05,  2.14it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  74%|███████████████████████████████▋           | 31/42 [00:14<00:05,  2.18it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  76%|████████████████████████████████▊          | 32/42 [00:15<00:04,  2.19it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  79%|█████████████████████████████████▊         | 33/42 [00:15<00:04,  2.19it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  81%|██████████████████████████████████▊        | 34/42 [00:16<00:03,  2.18it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  83%|███████████████████████████████████▊       | 35/42 [00:16<00:03,  2.21it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  86%|████████████████████████████████████▊      | 36/42 [00:16<00:02,  2.21it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  88%|█████████████████████████████████████▉     | 37/42 [00:17<00:02,  2.17it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  90%|██████████████████████████████████████▉    | 38/42 [00:17<00:01,  2.12it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  93%|███████████████████████████████████████▉   | 39/42 [00:18<00:01,  2.05it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  95%|████████████████████████████████████████▉  | 40/42 [00:18<00:00,  2.12it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  98%|█████████████████████████████████████████▉ | 41/42 [00:19<00:00,  2.12it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
# 100%|███████████████████████████████████████████| 42/42 [00:19<00:00,  2.12it/s]

# %%
ds_dict0 = gt.load.seaglider_basestation_netCDFs(filenames[-2], names,verbose=True)
print(ds_dict0)

ds_dict = gt.load.seaglider_basestation_netCDFs(filenames[19], names,verbose=True)
print(ds_dict)
# Out:
# /home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 170.11it/s]
# {'sg_data_point': <xarray.Dataset>
# Dimensions:    (sg_data_point: 2745)
# Dimensions without coordinates: sg_data_point
# Data variables:
#     time_dt64  (sg_data_point) datetime64[ns] 2019-05-09T06:32:16 ... 2019-05...
#     time       (sg_data_point) float64 1.557e+09 1.557e+09 ... 1.557e+09
#     latitude   (sg_data_point) float64 -25.94 -25.94 -25.94 ... -25.93 -25.93
#     depth      (sg_data_point) float64 1.15 1.15 1.15 1.19 ... 0.45 0.33 0.36
#     longitude  (sg_data_point) float64 -45.03 -45.03 -45.03 ... -45.07 -45.07
#     dives      (sg_data_point) float64 131.0 131.0 131.0 ... 131.5 131.5 131.5
# Attributes:
#     date_created:             2023-05-05 12:54:38
#     number_of_dives:          131.0
#     files:                    ['p6570131.nc']
#     time_coverage_start:      2019-05-09 06:32:16
#     time_coverage_end:        2019-05-09 13:59:35
#     geospatial_vertical_min:  0.3299976951105463
#     geospatial_vertical_max:  954.3107667064623
#     geospatial_lat_min:       -25.9412497982387
#     geospatial_lat_max:       -25.929149033961284
#     geospatial_lon_min:       -45.07204412205203
#     geospatial_lon_max:       -45.03290728958535
#     processing:               [2023-05-05 12:54:38] imported data with Glider...}
#
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
# /home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 163.22it/s]
# {'sg_data_point': <xarray.Dataset>
# Dimensions:    (sg_data_point: 804)
# Dimensions without coordinates: sg_data_point
# Data variables:
#     time_dt64  (sg_data_point) datetime64[ns] 2019-05-05T00:02:22 ... 2019-05...
#     time       (sg_data_point) float64 1.557e+09 1.557e+09 ... 1.557e+09
#     latitude   (sg_data_point) float64 -26.31 -26.31 -26.31 ... -26.3 -26.3
#     depth      (sg_data_point) float64 1.16 1.1 1.17 1.3 ... 3.93 2.52 1.04 0.16
#     longitude  (sg_data_point) float64 -45.04 -45.04 -45.04 ... -45.05 -45.05
#     dives      (sg_data_point) float64 52.0 52.0 52.0 52.0 ... 52.5 52.5 52.5
# Attributes:
#     date_created:             2023-05-05 12:54:38
#     number_of_dives:          52.0
#     files:                    ['p6570052.nc']
#     time_coverage_start:      2019-05-05 00:02:22
#     time_coverage_end:        2019-05-05 02:11:43
#     geospatial_vertical_min:  0.15999469823376591
#     geospatial_vertical_max:  932.4560034658997
#     geospatial_lat_min:       -26.305595276866253
#     geospatial_lat_max:       -26.296852027647212
#     geospatial_lon_min:       -45.04896971607767
#     geospatial_lon_max:       -45.03972502006388
#     processing:               [2023-05-05 12:54:38] imported data with Glider...}

# %%
date_to_plot = np.array([mdates.date2num(obspy.UTCDateTime(i).datetime) for i in ds_dict['sg_data_point']['time']])
depth_to_plot = np.array([i*-1 for i in ds_dict['sg_data_point']['depth']])

date_to_plot0 = np.array([mdates.date2num(obspy.UTCDateTime(i).datetime) for i in ds_dict0['sg_data_point']['time']])
depth_to_plot0 = np.array([i*-1 for i in ds_dict0['sg_data_point']['depth']])

# %%
# Create a figure
# set up the plot and create a GeoAxes:
proj = ccrs.PlateCarree()
fig, ax = plt.subplots(1, 1,figsize=(20,10), subplot_kw=dict(projection=proj))

# ----------------------------------------------------------------------------------------------------------
# Limit the extent of the map to a small longitude/latitude range.
latmin=-26.75
latmax=-25.5
lonmin=-47
lonmax=-43

ax.set_extent([lonmin,lonmax, latmin, latmax], crs=ccrs.Geodetic())

# ----------------------------------------------------------------------------------------------------------
# Ploting lat/lon values

h = ax.scatter(ds_dict_lst_lon,ds_dict_lst_lat,c=ds_dict_lst_time,marker='o',alpha=0.8,cmap='plasma',s=75,transform=proj)
# ----------------------------------------------------------------------------------------------------------
# Adding background map 
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE,linewidth=0.3)
ax.add_feature(cfeature.BORDERS, linestyle=':',linewidth=0.3)
ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,linewidth=1, color='gray', alpha=0.5, linestyle='--')

# ----------------------------------------------------------------------------------------------------------
# Adding colorbar
divider = make_axes_locatable(ax)
ax_cb = divider.new_horizontal(size="1%", pad=0.6, axes_class=plt.Axes)

fig.add_axes(ax_cb)
cb = plt.colorbar(h, cax=ax_cb)
cb.ax.yaxis.set_major_formatter(mdates.DateFormatter('%d/%m/%y'))

#####################################################
# Adding inset axes LEFT
#####################################################

# ----------------------------------------------------------------------------------------------------------
axins0 = plt.axes([0.2, 0.35, 0.2, 0.2],projection=proj)

dz0 = depth_to_plot0
norm = colors.Normalize(dz0.min(), dz0.max())
colors_map = cm.plasma(norm(dz0))
j0 = axins0.scatter(ds_dict0['sg_data_point']['longitude'], ds_dict0['sg_data_point']['latitude'], c=date_to_plot0,marker='.',alpha=0.7,cmap='twilight',s=50,transform=proj)

axins0.add_feature(cfeature.LAND)
axins0.add_feature(cfeature.OCEAN)
axins0.add_feature(cfeature.COASTLINE,linewidth=0.3)
axins0.add_feature(cfeature.BORDERS, linestyle=':',linewidth=0.3)
axins0.gridlines(crs=ccrs.PlateCarree(), draw_labels=["bottom", "left", "right"],linewidth=0.5, color='gray', alpha=0.5, linestyle='--')

# subregion of the original image
x10 = -45.085
x20 = -45.025
y10 = -25.95
y20 = -25.92

axins0.set_xlim(x10, x20)
axins0.set_ylim(y10, y20)
axins0.tick_params(axis='both',which="both",bottom=True, top=True, left=True, right=True,labelbottom=True, labeltop=False, labelleft=True, labelright=True)

# ----------------------------------------------------------------------------------------------------------
# Adding ZOOM
ax.indicate_inset_zoom(axins0, edgecolor="black")

# ----------------------------------------------------------------------------------------------------------
ax_histx0 = plt.axes([0.2, 0.56, 0.2, 0.1],sharex=axins0,facecolor='lightsteelblue')
ax_histx0.scatter(ds_dict0['sg_data_point']['longitude'], depth_to_plot0, c=date_to_plot0,marker='.',alpha=0.7,cmap='twilight',s=50)
ax_histx0.grid(linewidth=0.5, color='gray', alpha=0.5, linestyle='--')
ax_histx0.set_title("Dia:"+mdates.num2date(date_to_plot0[0]).strftime('%d/%m/%y')+"\n Mergulho:"+str(int(ds_dict0['sg_data_point'].attrs['number_of_dives'])))
ax_histx0.tick_params(axis='both',which="both",bottom=True, top=True, left=True, right=True,labelbottom=False, labeltop=False, labelleft=True, labelright=True)
ax_histx0.set_ylim(-1000,0)
ax_histx0.yaxis.set_major_formatter('{x} m')
ax_histx0.yaxis.set_major_locator(MultipleLocator(500))
ax_histx0.yaxis.set_minor_locator(MultipleLocator(100))

# ----------------------------------------------------------------------------------------------------------
# Adding colorbar

cax0 = plt.axes([0.2, 0.3, 0.2, 0.02])
date_colorbar0 = np.linspace(date_to_plot0.min(), date_to_plot0.max(), 4, endpoint=True)
cb0 = plt.colorbar(j0, cax=cax0,orientation='horizontal',ticks=date_colorbar0)
cb0.ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))

#####################################################
# Adding inset axes RIGHT
#####################################################

axins = plt.axes([0.625, 0.35, 0.2, 0.2],projection=proj)

dz = depth_to_plot
norm = colors.Normalize(dz.min(), dz.max())
colors_map = cm.plasma(norm(dz))
j = axins.scatter(ds_dict['sg_data_point']['longitude'], ds_dict['sg_data_point']['latitude'], c=date_to_plot,marker='.',alpha=0.7,cmap='twilight',s=50,transform=proj)

axins.add_feature(cfeature.LAND)
axins.add_feature(cfeature.OCEAN)
axins.add_feature(cfeature.COASTLINE,linewidth=0.3)
axins.add_feature(cfeature.BORDERS, linestyle=':',linewidth=0.3)
# ----------------------------------------------------------------------------------------------------------
# Adding grid 
axins.gridlines(crs=ccrs.PlateCarree(), draw_labels=["bottom", "left", "right"],linewidth=0.5, color='gray', alpha=0.5, linestyle='--')

# subregion of the original image
x1 = -45.055
x2 = -45.030
y1 = -26.3075
y2 = -26.295
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
axins.tick_params(axis='both',which="both",bottom=True, top=True, left=True, right=True,labelbottom=True, labeltop=False, labelleft=True, labelright=True)

# ----------------------------------------------------------------------------------------------------------
# Adding ZOOM
ax.indicate_inset_zoom(axins, edgecolor="black")

# ----------------------------------------------------------------------------------------------------------
ax_histx = plt.axes([0.625, 0.56, 0.2, 0.1],sharex=axins,facecolor='lightsteelblue')
ax_histx.scatter(ds_dict['sg_data_point']['longitude'], depth_to_plot, c=date_to_plot,marker='.',alpha=0.7,cmap='twilight',s=50)
ax_histx.grid(linewidth=0.5, color='gray', alpha=0.5, linestyle='--')
ax_histx.set_title("Dia:"+mdates.num2date(date_to_plot[0]).strftime('%d/%m/%y')+"\n Mergulho:"+str(int(ds_dict['sg_data_point'].attrs['number_of_dives'])))
ax_histx.tick_params(axis='both',which="both",bottom=True, top=True, left=True, right=True,labelbottom=False, labeltop=False, labelleft=True, labelright=True)
ax_histx.set_ylim(-1000,0)
ax_histx.yaxis.set_major_formatter('{x} m')
ax_histx.yaxis.set_major_locator(MultipleLocator(500))
ax_histx.yaxis.set_minor_locator(MultipleLocator(100))

# ----------------------------------------------------------------------------------------------------------
# Adding colorbar
cax = plt.axes([0.625, 0.3, 0.2, 0.02])
date_colorbar = np.linspace(date_to_plot.min(), date_to_plot.max(), 4, endpoint=True)
cb = plt.colorbar(j, cax=cax,orientation='horizontal',ticks=date_colorbar)
cb.ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
# ----------------------------------------------------------------------------------------------------------
# Adding global location map
# inset location relative to main plot (ax) in normalized units
inset_x = 0
inset_y = 1
inset_size = 0.5

# Adding Geoaxes
ax2 = plt.axes([0, 0, 1, 1], projection=ccrs.Orthographic(central_latitude=(latmin + latmax)/2,central_longitude=(lonmin + lonmax) / 2))
ax2.set_global()

# Adding background map 
ax2.add_feature(cfeature.LAND)
ax2.add_feature(cfeature.OCEAN)
ax2.add_feature(cfeature.COASTLINE)

# Adding inset geoaxes position
ip = InsetPosition(ax, [inset_x - inset_size / 2,
                        inset_y - inset_size / 2,
                        inset_size,
                        inset_size])
ax2.set_axes_locator(ip)


# Adding red rectangle position
nvert = 100
lons = np.r_[np.linspace(lonmin, lonmin, nvert),
             np.linspace(lonmin, lonmax, nvert),
             np.linspace(lonmax, lonmax, nvert)].tolist()
lats = np.r_[np.linspace(latmin, latmax, nvert),
             np.linspace(latmax, latmax, nvert),
             np.linspace(latmax, latmin, nvert)].tolist()

ring = LinearRing(list(zip(lons, lats)))
ax2.add_geometries([ring], ccrs.PlateCarree(),
                   facecolor='none', edgecolor='red', linewidth=0.75)

# %% [markdown]
# # Gráfico Geral

# %%
os.chdir('/run/media/dIOGOLOC/8d2362fc-3b46-49a7-a864-19b2a6ad097b/diogoloc/dados_posdoc/gliders_project/gliders_data/NetCDF_data/')

# %%
filenames = sorted(glob.glob('*/*.nc'))

# %%
print(len(filenames))
# Out:
# 1467

# %%
#Attributes:
#    date_created:             2023-05-04 18:27:38
#    number_of_dives:          52.0
#    files:                    ['p6570052.nc']
#    time_coverage_start:      2019-05-05 00:02:22
#    time_coverage_end:        2019-05-05 02:11:43
#    geospatial_vertical_min:  0.15999469823376591
#    geospatial_vertical_max:  932.4560034658997
#    geospatial_lat_min:       -26.305595276866253
#    geospatial_lat_max:       -26.296852027647212
#    geospatial_lon_min:       -45.04896971607767
#    geospatial_lon_max:       -45.03972502006388

# %%
ds_dict_lst_lat = []
ds_dict_lst_lon = []
ds_dict_lst_dpt = []
ds_dict_lst_time = []
ds_dict_lst_timelapse = []
ds_dict_lst_dive = []

for i in tqdm(filenames):
    dic_ds = gt.load.seaglider_basestation_netCDFs(i, names,verbose=False)
    ds_dict_lst_dive.append(dic_ds['sg_data_point'].attrs['number_of_dives'])
    ds_dict_lst_lat.append(dic_ds['sg_data_point'].attrs['geospatial_lat_min'])
    ds_dict_lst_lon.append(dic_ds['sg_data_point'].attrs['geospatial_lon_min'])
    ds_dict_lst_dpt.append(dic_ds['sg_data_point'].attrs['geospatial_vertical_max']*-1)
    ds_dict_lst_time.append(mdates.date2num(obspy.UTCDateTime(dic_ds['sg_data_point'].attrs['time_coverage_start'])))
    ds_dict_lst_timelapse.append(obspy.UTCDateTime(dic_ds['sg_data_point'].attrs['time_coverage_end'])-obspy.UTCDateTime(dic_ds['sg_data_point'].attrs['time_coverage_start']))
# Out:
#   0%|                                                  | 0/1467 [00:00<?, ?it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   0%|                                          | 1/1467 [00:00<16:06,  1.52it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   0%|                                          | 2/1467 [00:01<13:02,  1.87it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   0%|                                          | 3/1467 [00:01<12:02,  2.03it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   0%|                                          | 4/1467 [00:02<12:28,  1.95it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   0%|▏                                         | 5/1467 [00:02<11:59,  2.03it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   0%|▏                                         | 6/1467 [00:02<11:38,  2.09it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   0%|▏                                         | 7/1467 [00:03<11:22,  2.14it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   1%|▏                                         | 8/1467 [00:03<11:14,  2.16it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   1%|▎                                         | 9/1467 [00:04<10:57,  2.22it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   1%|▎                                        | 10/1467 [00:04<11:41,  2.08it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   1%|▎                                        | 11/1467 [00:05<11:36,  2.09it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   1%|▎                                        | 12/1467 [00:05<11:31,  2.11it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   1%|▎                                        | 13/1467 [00:06<11:40,  2.08it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   1%|▍                                        | 14/1467 [00:06<11:51,  2.04it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   1%|▍                                        | 15/1467 [00:07<12:13,  1.98it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   1%|▍                                        | 16/1467 [00:07<11:50,  2.04it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   1%|▍                                        | 17/1467 [00:08<11:16,  2.14it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   1%|▌                                        | 18/1467 [00:08<11:08,  2.17it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   1%|▌                                        | 19/1467 [00:09<11:00,  2.19it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   1%|▌                                        | 20/1467 [00:09<10:52,  2.22it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   1%|▌                                        | 21/1467 [00:09<10:48,  2.23it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   1%|▌                                        | 22/1467 [00:10<10:45,  2.24it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   2%|▋                                        | 23/1467 [00:10<10:40,  2.25it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   2%|▋                                        | 24/1467 [00:11<11:32,  2.08it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   2%|▋                                        | 25/1467 [00:11<11:25,  2.10it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   2%|▋                                        | 26/1467 [00:12<11:52,  2.02it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   2%|▊                                        | 27/1467 [00:12<11:41,  2.05it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   2%|▊                                        | 28/1467 [00:13<11:31,  2.08it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   2%|▊                                        | 29/1467 [00:13<11:15,  2.13it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   2%|▊                                        | 30/1467 [00:14<11:19,  2.12it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   2%|▊                                        | 31/1467 [00:14<11:16,  2.12it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   2%|▉                                        | 32/1467 [00:15<11:14,  2.13it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   2%|▉                                        | 33/1467 [00:15<11:34,  2.06it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   2%|▉                                        | 34/1467 [00:16<11:53,  2.01it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#   2%|▉                                        | 35/1467 [00:16<12:46,  1.87it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#
/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  99%|██████████████████████████████████████▍| 1445/1467 [11:37<00:10,  2.17it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  99%|██████████████████████████████████████▍| 1446/1467 [11:38<00:09,  2.20it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  99%|██████████████████████████████████████▍| 1447/1467 [11:38<00:09,  2.21it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  99%|██████████████████████████████████████▍| 1448/1467 [11:39<00:08,  2.22it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  99%|██████████████████████████████████████▌| 1449/1467 [11:39<00:08,  2.11it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  99%|██████████████████████████████████████▌| 1450/1467 [11:40<00:08,  2.07it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  99%|██████████████████████████████████████▌| 1451/1467 [11:40<00:08,  1.97it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  99%|██████████████████████████████████████▌| 1452/1467 [11:41<00:07,  2.00it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  99%|██████████████████████████████████████▋| 1453/1467 [11:41<00:06,  2.06it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  99%|██████████████████████████████████████▋| 1454/1467 [11:42<00:06,  2.11it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  99%|██████████████████████████████████████▋| 1455/1467 [11:42<00:05,  2.14it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  99%|██████████████████████████████████████▋| 1456/1467 [11:43<00:05,  2.13it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  99%|██████████████████████████████████████▋| 1457/1467 [11:43<00:04,  2.05it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  99%|██████████████████████████████████████▊| 1458/1467 [11:44<00:04,  2.00it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
#  99%|██████████████████████████████████████▊| 1459/1467 [11:44<00:04,  1.79it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
# 100%|██████████████████████████████████████▊| 1460/1467 [11:45<00:03,  1.85it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
# 100%|██████████████████████████████████████▊| 1461/1467 [11:46<00:03,  1.75it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
# 100%|██████████████████████████████████████▊| 1462/1467 [11:46<00:02,  1.67it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
# 100%|██████████████████████████████████████▉| 1463/1467 [11:47<00:02,  1.57it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
# 100%|██████████████████████████████████████▉| 1464/1467 [11:47<00:01,  1.64it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
# 100%|██████████████████████████████████████▉| 1465/1467 [11:48<00:01,  1.76it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
# 100%|██████████████████████████████████████▉| 1466/1467 [11:49<00:00,  1.70it/s]/home/dIOGOLOC/programs/anaconda3/lib/python3.10/site-packages/glidertools/load/seaglider.py:227: GliderToolsWarning: dives was not found in the files
#   warnings.warn(msg, GliderToolsWarning)
# DIMENSION: sg_data_point
# {time, latitude, depth, longitude}
# 100%|███████████████████████████████████████| 1467/1467 [11:49<00:00,  2.07it/s]

# %%
mdates.num2date(min(ds_dict_lst_time)).strftime('%d/%m/%y')
# Out:
# '07/11/18'

# %%
mdates.num2date(max(ds_dict_lst_time)).strftime('%d/%m/%y')
# Out:
# '09/05/19'

# %%
# Create a figure
# set up the plot and create a GeoAxes:
proj = ccrs.PlateCarree()
fig, (ax,ax1,ax2,ax3) = plt.subplots(1, 4,figsize=(20,5), subplot_kw=dict(projection=proj),sharey=True)

# ----------------------------------------------------------------------------------------------------------
# Limit the extent of the map to a small longitude/latitude range.
latmin=-28.5
latmax=-22
lonmin=-49
lonmax=-40

# ----------------------------------------------------------------------------------------------------------
# Ploting lat/lon values date
ax.set_extent([lonmin,lonmax, latmin, latmax], crs=ccrs.Geodetic())

h = ax.scatter(ds_dict_lst_lon,ds_dict_lst_lat,c=ds_dict_lst_time,vmin=min(ds_dict_lst_time),vmax=max(ds_dict_lst_time),marker='o',alpha=0.5,cmap='plasma',s=75,transform=proj)

# ----------------------------------------------------------------------------------------------------------
# Adding background map 
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE,linewidth=0.3)
ax.add_feature(cfeature.BORDERS, linestyle=':',linewidth=0.3)
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.right_labels = False

# ----------------------------------------------------------------------------------------------------------
# Adding shape file:
ax.add_geometries(shpreader.Reader(filename='/run/media/dIOGOLOC/8d2362fc-3b46-49a7-a864-19b2a6ad097b/diogoloc/dados_posdoc/SIG_Dados/shapes/Bacias Sedimentares/bacia_de_santos.shp').geometries(),crs=ccrs.PlateCarree(),fc='none',ec='k',ls='--')

# ----------------------------------------------------------------------------------------------------------
# Adding colorbar
date_colorbar_total = np.linspace(min(ds_dict_lst_time),max(ds_dict_lst_time), 4, endpoint=True)

divider = make_axes_locatable(ax)
ax_cb = divider.append_axes("bottom",size="2%", pad=0.6, axes_class=plt.Axes)

fig.add_axes(ax_cb)
cb = plt.colorbar(h, cax=ax_cb,orientation='horizontal',label='Início do mergulho (mês-ano)',ticks=date_colorbar_total)
cb.ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%y'))

# ----------------------------------------------------------------------------------------------------------
# Ploting lat/lon values depth

ax1.set_extent([lonmin,lonmax, latmin, latmax], crs=ccrs.Geodetic())

g = ax1.scatter(ds_dict_lst_lon,ds_dict_lst_lat,c=ds_dict_lst_dpt,vmin=0,vmax=-1000,marker='o',alpha=0.5,cmap='cividis',s=75,transform=proj)
# ----------------------------------------------------------------------------------------------------------
# Adding background map 
ax1.add_feature(cfeature.LAND)
ax1.add_feature(cfeature.OCEAN)
ax1.add_feature(cfeature.COASTLINE,linewidth=0.3)
ax1.add_feature(cfeature.BORDERS, linestyle=':',linewidth=0.3)
gl1 = ax1.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl1.left_labels = False
gl1.right_labels = False

# ----------------------------------------------------------------------------------------------------------
# Adding shape file:
ax1.add_geometries(shpreader.Reader(filename='/run/media/dIOGOLOC/8d2362fc-3b46-49a7-a864-19b2a6ad097b/diogoloc/dados_posdoc/SIG_Dados/shapes/Bacias Sedimentares/bacia_de_santos.shp').geometries(),crs=ccrs.PlateCarree(),fc='none',ec='k',ls='--')

# ----------------------------------------------------------------------------------------------------------
# Adding colorbar
divider1 = make_axes_locatable(ax1)
ax_cb1 = divider1.append_axes("bottom",size="2%", pad=0.6, axes_class=plt.Axes)

fig.add_axes(ax_cb1)
cb1 = plt.colorbar(g, cax=ax_cb1,orientation='horizontal',label='Profundidade máxima do mergulho (m)')

# ----------------------------------------------------------------------------------------------------------
# Ploting lat/lon values dive

ax2.set_extent([lonmin,lonmax, latmin, latmax], crs=ccrs.Geodetic())

i = ax2.scatter(ds_dict_lst_lon,ds_dict_lst_lat,c=ds_dict_lst_dive,vmin=0,vmax=500,marker='o',alpha=0.5,cmap='viridis',s=75,transform=proj)
# ----------------------------------------------------------------------------------------------------------
# Adding background map 
ax2.add_feature(cfeature.LAND)
ax2.add_feature(cfeature.OCEAN)
ax2.add_feature(cfeature.COASTLINE,linewidth=0.3)
ax2.add_feature(cfeature.BORDERS, linestyle=':',linewidth=0.3)
gl2 = ax2.gridlines(crs=ccrs.PlateCarree(),draw_labels=True,linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl2.left_labels = False
gl2.right_labels = False

# ----------------------------------------------------------------------------------------------------------
# Adding shape file:
ax2.add_geometries(shpreader.Reader(filename='/run/media/dIOGOLOC/8d2362fc-3b46-49a7-a864-19b2a6ad097b/diogoloc/dados_posdoc/SIG_Dados/shapes/Bacias Sedimentares/bacia_de_santos.shp').geometries(),crs=ccrs.PlateCarree(),fc='none',ec='k',ls='--')

# ----------------------------------------------------------------------------------------------------------
# Adding colorbar
divider2 = make_axes_locatable(ax2)
ax_cb2 = divider2.append_axes("bottom",size="2%", pad=0.6, axes_class=plt.Axes)

fig.add_axes(ax_cb2)
cb2 = plt.colorbar(i, cax=ax_cb2,orientation='horizontal',label='Número do mergulho (id)')

# ----------------------------------------------------------------------------------------------------------
# Ploting lat/lon values timelapse

ax3.set_extent([lonmin,lonmax, latmin, latmax], crs=ccrs.Geodetic())

w = ax3.scatter(ds_dict_lst_lon,ds_dict_lst_lat,c=np.array([i/3600 for i in ds_dict_lst_timelapse]),vmin=0,vmax=6,marker='o',alpha=0.5,cmap='inferno',s=75,transform=proj)
# ----------------------------------------------------------------------------------------------------------
# Adding background map 
ax3.add_feature(cfeature.LAND)
ax3.add_feature(cfeature.OCEAN)
ax3.add_feature(cfeature.COASTLINE,linewidth=0.3)
ax3.add_feature(cfeature.BORDERS, linestyle=':',linewidth=0.3)
gl3 = ax3.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl3.left_labels = False

# ----------------------------------------------------------------------------------------------------------
# Adding shape file:
ax3.add_geometries(shpreader.Reader(filename='/run/media/dIOGOLOC/8d2362fc-3b46-49a7-a864-19b2a6ad097b/diogoloc/dados_posdoc/SIG_Dados/shapes/Bacias Sedimentares/bacia_de_santos.shp').geometries(),crs=ccrs.PlateCarree(),fc='none',ec='k',ls='--')

# ----------------------------------------------------------------------------------------------------------
# Adding colorbar
divider3 = make_axes_locatable(ax3)
ax_cb3 = divider3.append_axes("bottom",size="2%", pad=0.6, axes_class=plt.Axes)

fig.add_axes(ax_cb3)
cb3 = plt.colorbar(w, cax=ax_cb3,orientation='horizontal',label='Duração do mergulho (horas)')
output_folder = FOLDER_OUTPUT+'FIGURAS/MERGULHOS_INFO/'
os.makedirs(output_folder,exist_ok=True)
fig.savefig(fname=output_folder+'gliders_'+mdates.num2date(min(ds_dict_lst_time)).strftime('%b_%y')+'_'+mdates.num2date(max(ds_dict_lst_time)).strftime('%b_%y')+'.png',dpi=300)
