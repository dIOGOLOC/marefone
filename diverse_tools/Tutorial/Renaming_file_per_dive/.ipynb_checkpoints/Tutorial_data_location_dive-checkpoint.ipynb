# %% [markdown]
# # Importando módulos

# %%
import obspy
from obspy.taup import TauPyModel

from multiprocessing import Pool
from obspy import read,UTCDateTime,Trace
from obspy.clients.fdsn import Client
import os
import glob
import numpy as np
from collections import defaultdict
import pandas as pd

#para plotar as figuras
import matplotlib.pyplot as plt
from matplotlib.transforms import offset_copy
import matplotlib.ticker as ticker
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import ListedColormap
import matplotlib.dates as mdates
from mpl_toolkits.axes_grid1.inset_locator import InsetPosition,inset_axes
import matplotlib.colors as colors
import matplotlib.cm as cm
from matplotlib.dates import YearLocator, MonthLocator, DayLocator, HourLocator, MinuteLocator, SecondLocator, DateFormatter
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

from datetime import datetime,timedelta,date
from tqdm import tqdm

from shapely.geometry.polygon import LinearRing

import cartopy.io.shapereader as shpreader
import cartopy.crs as ccrs
import cartopy.feature as cfeature

from IPython.display import HTML
from IPython import display

# %% [markdown]
# # Inputs e Outputs

# %%
FOLDER_OUTPUT = '/media/sysop/8d2362fc-3b46-49a7-a864-19b2a6ad097b/diogoloc/dados_posdoc/gliders_project/OUTPUT/'

MSEED_INPUT = "/media/sysop/8d2362fc-3b46-49a7-a864-19b2a6ad097b/diogoloc/dados_posdoc/gliders_project/OUTPUT/MSEED/"

METADATA_OUTPUT = "/media/sysop/8d2362fc-3b46-49a7-a864-19b2a6ad097b/diogoloc/dados_posdoc/gliders_project/OUTPUT/METADATA/"

filename_csv = '/media/sysop/8d2362fc-3b46-49a7-a864-19b2a6ad097b/diogoloc/dados_posdoc/gliders_project/gliders_data/info_csv/metadados_glider_acustico_pmpas-bs.csv'

# %% [markdown]
# # Extraindo informações da tabela com os novos nomes dos arquivos (.feather)

# %%
df_mergulho_feather = pd.read_feather('/media/sysop/8d2362fc-3b46-49a7-a864-19b2a6ad097b/diogoloc/dados_posdoc/gliders_project/gliders_data/info_csv/df_mergulho.feather')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Programs/miniconda3/lib/python3.11/site-packages/pandas/compat/_optional.py:132, in import_optional_dependency(name, extra, errors, min_version)
#     131 try:
# --> 132     module = importlib.import_module(name)
#     133 except ImportError:
#
# File ~/Programs/miniconda3/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'pyarrow'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_mergulho_feather = pd.read_feather('/media/sysop/8d2362fc-3b46-49a7-a864-19b2a6ad097b/diogoloc/dados_posdoc/gliders_project/gliders_data/info_csv/df_mergulho.feather')
#
# File ~/Programs/miniconda3/lib/python3.11/site-packages/pandas/io/feather_format.py:117, in read_feather(path, columns, use_threads, storage_options, dtype_backend)
#      72 @doc(storage_options=_shared_docs["storage_options"])
#      73 def read_feather(
#      74     path: FilePath | ReadBuffer[bytes],
#    (...)
#      78     dtype_backend: DtypeBackend | lib.NoDefault = lib.no_default,
#      79 ) -> DataFrame:
#      80     """
#      81     Load a feather-format object from the file path.
#      82
#    (...)
#     115     >>> df = pd.read_feather("path/to/file.feather")  # doctest: +SKIP
#     116     """
# --> 117     import_optional_dependency("pyarrow")
#     118     from pyarrow import feather
#     120     # import utils to register the pyarrow extension types
#
# File ~/Programs/miniconda3/lib/python3.11/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     133 except ImportError:
#     134     if errors == "raise":
# --> 135         raise ImportError(msg)
#     136     return None
#     138 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'pyarrow'.  Use pip or conda to install pyarrow.

# %%
df_mergulho_feather
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_mergulho_feather
#
# NameError: name 'df_mergulho_feather' is not defined

# %% [markdown]
# # Extraindo informações dos arquivos ".mseed"

# %%
filenames_MSEED = sorted(glob.glob(MSEED_INPUT+'*/*/*.mseed'))

# %%
def mergulho_start_end_time(k):
    try:
        
        files_mseed_HD = [i for i in filenames_MSEED if i.split('/')[-1].split('.')[0] in k[1]['filename_mseed'].tolist()]
        
        tr_start = obspy.read(files_mseed_HD[0],headonly=True)[0]

        tr_end = obspy.read(files_mseed_HD[-1],headonly=True)[0]
        
        filename_mseed_HD = [i.split('/')[-1].split('.')[0] for i in files_mseed_HD]
        df_file = k[1].to_frame()

        df_nettab = df_file.T
        df_nettab['date_start_nettab'] = tr_start.stats.starttime.strftime('%Y/%j:%H%M')
        df_nettab['date_end_nettab'] = tr_end.stats.endtime.strftime('%Y/%j:%H%M')
        df_nettab['filename_mseed_HD'] = [filename_mseed_HD]

        return df_nettab
    
    except:
        pass

# %%
end_time = []
with Pool(processes=4) as p:
    with tqdm(total=len(df_mergulho_feather)) as pbar:
        for result in p.imap_unordered(mergulho_start_end_time,df_mergulho_feather.iterrows()):
            pbar.update()
            end_time.append(result)
# Out:
# 100%|███████████████████████████████████████| 4118/4118 [08:34<00:00,  8.00it/s]

# %%
dataframe_mseed_final = pd.concat(end_time, ignore_index=True)

# %%
dataframe_mseed_final.sort_values(by='time')
# Out:
#             date mergulho                        time  \
# 0     2015-11-12     0001  2015-11-12 13:48:40.999995
# 1     2015-11-12     0002  2015-11-12 14:36:17.999998
# 2     2015-11-12     0003  2015-11-12 15:35:47.999997
# 3     2015-11-12     0004  2015-11-12 17:42:06.999996
# 5     2015-11-12     0005  2015-11-12 20:43:35.999996
# ...          ...      ...                         ...
# 3913  2021-11-02     0288  2021-11-02 12:40:25.000003
# 3914  2021-11-03     0291  2021-11-03 03:38:04.000003
# 3916  2021-11-03     0292  2021-11-03 09:16:41.000002
# 3915  2021-11-04     0295  2021-11-04 00:25:55.999999
# 3917  2021-11-04     0296  2021-11-04 05:03:37.999998
#
#                                          filename_mseed        lat        lon  \
# 0     [pa0001au_001_151112_134841, pa0001au_002_1511... -23.824435 -42.495496
# 1     [pa0002au_001_151112_143618, pa0002au_002_1511... -23.816693 -42.494423
# 2     [pa0003au_001_151112_153548, pa0003au_002_1511... -23.807137 -42.487275
# 3     [pa0004au_001_151112_174207, pa0004au_002_1511... -23.790957 -42.473373
# 5     [pa0005au_001_151112_204336, pa0005au_002_1511... -23.785264 -42.469056
# ...                                                 ...        ...        ...
# 3913  [pa0288au_001_211102_124025, pa0288au_002_2111... -24.334206 -42.434063
# 3914  [pa0291au_001_211103_033804, pa0291au_002_2111... -24.356838 -42.425637
# 3916  [pa0292au_001_211103_091641, pa0292au_002_2111... -24.378415 -42.430636
# 3915  [pa0295au_001_211104_002556, pa0295au_002_2111... -24.437741 -42.464982
# 3917  [pa0296au_001_211104_050338, pa0296au_002_2111... -24.456913 -42.469915
#
#              dep      date_nettab station_nettab date_start_nettab  \
# 0       28.10798  2015/316[:1348]          G1348   2015/316[:1348]
# 1      54.389724  2015/316[:1436]          G1436   2015/316[:1436]
# 2      159.71917  2015/316[:1535]          G1535   2015/316[:1535]
# 3     264.914544  2015/316[:1742]          G1742   2015/316[:1742]
# 5     283.000283  2015/316[:2043]          G2043   2015/316[:2043]
# ...          ...              ...            ...               ...
# 3913  490.726565  2021/306[:1240]          G1240   2021/306[:1240]
# 3914  509.938108  2021/307[:0338]          G0338   2021/307[:0338]
# 3916  500.532732  2021/307[:0916]          G0916   2021/307[:0916]
# 3915  460.269513  2021/308[:0025]          G0025   2021/308[:0025]
# 3917  469.603228  2021/308[:0503]          G0503   2021/308[:0503]
#
#       date_end_nettab                                  filename_mseed_HD
# 0     2015/316[:1356]  [pa0001au_001_151112_134841, pa0001au_002_1511...
# 1     2015/316[:1450]  [pa0002au_001_151112_143618, pa0002au_002_1511...
# 2     2015/316[:1615]  [pa0003au_001_151112_153548, pa0003au_002_1511...
# 3     2015/316[:1843]  [pa0004au_001_151112_174207, pa0004au_002_1511...
# 5     2015/316[:2147]  [pa0005au_001_151112_204336, pa0005au_002_1511...
# ...               ...                                                ...
# 3913  2021/306[:1518]  [pa0288au_001_211102_124025, pa0288au_002_2111...
# 3914  2021/307[:0609]  [pa0291au_001_211103_033804, pa0291au_002_2111...
# 3916  2021/307[:1150]  [pa0292au_001_211103_091641, pa0292au_002_2111...
# 3915  2021/308[:0219]  [pa0295au_001_211104_002556, pa0295au_002_2111...
# 3917  2021/308[:0657]  [pa0296au_001_211104_050338, pa0296au_002_2111...
#
# [3918 rows x 12 columns]

# %%
dataframe_mseed_name = dataframe_mseed_final.drop(columns=['station_nettab'])

# %%
mergulho_name = []
for i in dataframe_mseed_final.iterrows():
    mergulho_name.append(i[1]['mergulho'][1:])

# %%
dataframe_mseed_name['mergulho_nettab'] = np.array(mergulho_name)

# %%
station_nettab_lst = []
for i in dataframe_mseed_name['date']:
    station_nettab_lst.append(i.strftime("%y%j"))

# %%
dataframe_mseed_name['station_nettab'] = np.array(station_nettab_lst)

# %%
dataframe_mseed_name
# Out:
#             date mergulho                        time  \
# 0     2015-11-12     0001  2015-11-12 13:48:40.999995
# 1     2015-11-12     0002  2015-11-12 14:36:17.999998
# 2     2015-11-12     0003  2015-11-12 15:35:47.999997
# 3     2015-11-12     0004  2015-11-12 17:42:06.999996
# 4     2015-11-12     0006  2015-11-12 23:59:13.000003
# ...          ...      ...                         ...
# 3913  2021-11-02     0288  2021-11-02 12:40:25.000003
# 3914  2021-11-03     0291  2021-11-03 03:38:04.000003
# 3915  2021-11-04     0295  2021-11-04 00:25:55.999999
# 3916  2021-11-03     0292  2021-11-03 09:16:41.000002
# 3917  2021-11-04     0296  2021-11-04 05:03:37.999998
#
#                                          filename_mseed        lat        lon  \
# 0     [pa0001au_001_151112_134841, pa0001au_002_1511... -23.824435 -42.495496
# 1     [pa0002au_001_151112_143618, pa0002au_002_1511... -23.816693 -42.494423
# 2     [pa0003au_001_151112_153548, pa0003au_002_1511... -23.807137 -42.487275
# 3     [pa0004au_001_151112_174207, pa0004au_002_1511... -23.790957 -42.473373
# 4                          [pa0006au_001_151112_235913] -23.780344 -42.469132
# ...                                                 ...        ...        ...
# 3913  [pa0288au_001_211102_124025, pa0288au_002_2111... -24.334206 -42.434063
# 3914  [pa0291au_001_211103_033804, pa0291au_002_2111... -24.356838 -42.425637
# 3915  [pa0295au_001_211104_002556, pa0295au_002_2111... -24.437741 -42.464982
# 3916  [pa0292au_001_211103_091641, pa0292au_002_2111... -24.378415 -42.430636
# 3917  [pa0296au_001_211104_050338, pa0296au_002_2111... -24.456913 -42.469915
#
#              dep      date_nettab date_start_nettab  date_end_nettab  \
# 0       28.10798  2015/316[:1348]   2015/316[:1348]  2015/316[:1356]
# 1      54.389724  2015/316[:1436]   2015/316[:1436]  2015/316[:1450]
# 2      159.71917  2015/316[:1535]   2015/316[:1535]  2015/316[:1615]
# 3     264.914544  2015/316[:1742]   2015/316[:1742]  2015/316[:1843]
# 4          8.517  2015/316[:2359]   2015/316[:2359]  2015/317[:0001]
# ...          ...              ...               ...              ...
# 3913  490.726565  2021/306[:1240]   2021/306[:1240]  2021/306[:1518]
# 3914  509.938108  2021/307[:0338]   2021/307[:0338]  2021/307[:0609]
# 3915  460.269513  2021/308[:0025]   2021/308[:0025]  2021/308[:0219]
# 3916  500.532732  2021/307[:0916]   2021/307[:0916]  2021/307[:1150]
# 3917  469.603228  2021/308[:0503]   2021/308[:0503]  2021/308[:0657]
#
#                                       filename_mseed_HD mergulho_nettab  \
# 0     [pa0001au_001_151112_134841, pa0001au_002_1511...             001
# 1     [pa0002au_001_151112_143618, pa0002au_002_1511...             002
# 2     [pa0003au_001_151112_153548, pa0003au_002_1511...             003
# 3     [pa0004au_001_151112_174207, pa0004au_002_1511...             004
# 4                          [pa0006au_001_151112_235913]             006
# ...                                                 ...             ...
# 3913  [pa0288au_001_211102_124025, pa0288au_002_2111...             288
# 3914  [pa0291au_001_211103_033804, pa0291au_002_2111...             291
# 3915  [pa0295au_001_211104_002556, pa0295au_002_2111...             295
# 3916  [pa0292au_001_211103_091641, pa0292au_002_2111...             292
# 3917  [pa0296au_001_211104_050338, pa0296au_002_2111...             296
#
#      station_nettab
# 0             15316
# 1             15316
# 2             15316
# 3             15316
# 4             15316
# ...             ...
# 3913          21306
# 3914          21307
# 3915          21308
# 3916          21307
# 3917          21308
#
# [3918 rows x 13 columns]

# %%
lines_nettab = []
for i in dataframe_mseed_final.iterrows():
    # Station lines (one line per station/sensor/epoch) # code description datalogger%sn seismometer%sn # sampling orientation lat. lon. elev. depth. start end
    #Sl: UNAP "Uni-Iquique/Chile"   DM24%A1383 CMG-3ESP/60%T34622 100 ZNE -20.24393 -70.14041 0.0    0.0 2009/134 
       
    lines_nettab.append('Sl: '+i[1].station_nettab+' Glider:PMPAS-BS'+' SENSOR'+' '+'REGISTER'+' 100 Z '+str(i[1].lat)+' '+str(i[1].lon)+' 0 0 '+i[1].date_start_nettab+' '+i[1].date_end_nettab)

# %%
with open('/media/sysop/8d2362fc-3b46-49a7-a864-19b2a6ad097b/diogoloc/dados_posdoc/gliders_project/gliders_data/info_csv/df_mergulho_nettab.txt', 'w') as f:
    for line in lines_nettab:
        f.write(line)
        f.write('\n')

# %% [markdown]
# # Renomeando os arquivos ".mseed":

# %%
def rename_files(k):
    
    files_mseed_HD = k[1]['filename_mseed_HD']
    
    files_path_mseed_HD = [glob.glob(MSEED_INPUT+'*/*/*'+i+'.mseed') for i in files_mseed_HD]
    for y in files_path_mseed_HD:
        
        st = obspy.read(y[0])
        st[0].stats.network = 'GL'
        st[0].stats.station = k[1]['station_nettab']
        st[0].stats.location = k[1]['mergulho_nettab']
        st[0].stats.channel = 'HHH'

        #<SDSdir>/Year/NET/STA/CHAN.TYPE/NET.STA.LOC.CHAN.TYPE.YEAR.DAY
        #Saving in SDS structure        
        OUTPUT_STREAM = FOLDER_OUTPUT+'MSEED_SDS/'+st[0].stats.starttime.strftime("%Y")+'/'+st[0].stats.network+'/'+st[0].stats.station+'/HHH.D/'
        os.makedirs(OUTPUT_STREAM,exist_ok=True)
        
        station_name_file = st[0].stats.network+'.'+st[0].stats.station+'..'+st[0].stats.channel+'.D.'+st[0].stats.starttime.strftime("%Y.%j")+'.'+y[0].split('/')[-1]
        if os.path.exists(OUTPUT_STREAM+station_name_file) == False:
            st.write(OUTPUT_STREAM+station_name_file, format='MSEED')

# %%
with Pool(processes=4) as p:
    with tqdm(total=len(df_mergulho_feather)) as pbar:
        for result in p.imap_unordered(rename_files,dataframe_mseed_final.iterrows()):
            pbar.update()
# Out:
#  95%|███████████████████████████████████▏ | 3918/4118 [1:44:50<05:21,  1.61s/it]
